# %%
import pandas as pd

# %%
file_path=r"C:\Users\karthick\COVID-19.xlsx"
covid19_data=pd.read_excel(file_path,sheet_name=[Current_shift_performance]) #deafult sheet is first sheet
covid19_data

# %%
file_path = r"C:\Users\15878\DA\17-04-2023-SGD-P2-Performance.xlsx"
OEE_file=pd.read_excel(file_path,sheet_name=[0])
OEE_file
# Out:
# {0:                     Date   Line_Name Machine_Name Shift/Hour         Pdt_name  \
#  0    2023-04-17 00:00:00      12 LPM        ACE-4    (06-07)             N-20
#  1    2023-04-17 00:00:00      12 LPM        ACE-4    (07-08)             N-20
#  2    2023-04-17 00:00:00      12 LPM        ACE-4    (08-09)             N-20
#  3    2023-04-17 00:00:00      12 LPM        ACE-4    (09-10)             N-20
#  4    2023-04-17 00:00:00      12 LPM        ACE-4    (10-11)             N-20
#  ..                   ...         ...          ...        ...              ...
#  185  2023-04-17 00:00:00  Shaft line       MGTL-1    (03-04)  Double Diameter
#  186  2023-04-17 00:00:00  Shaft line       MGTL-1    (04-05)  Double Diameter
#  187  2023-04-17 00:00:00  Shaft line       MGTL-1    (05-06)  Double Diameter
#  188  2023-04-17 00:00:00  Shaft line       MGTL-1    (22-23)  Double Diameter
#  189  2023-04-17 00:00:00  Shaft line       MGTL-1    (23-00)  Double Diameter
#
# ...

# %%
import pandas as pd
oee_data=pd.read_csv(r"C:\Users\15878\DA\DAreport.csv")
oee_data
# Out:
#             Date En_Name   Bg_Name Plant_Name         Line_Name Machine_Name  \
# 0     04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        HMC-4
# 1     04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        HMC-4
# 2     04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        HMC-4
# 3     04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        HMC-4
# 4     04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        HMC-4
# ...          ...     ...       ...        ...               ...          ...
# 2160  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
# 2161  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
# 2162  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
# 2163  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
# 2164  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
#
# ...

# %%
oee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2165 entries, 0 to 2164
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             2165 non-null   object
#  1   En_Name          2165 non-null   object
#  2   Bg_Name          2165 non-null   object
#  3   Plant_Name       2165 non-null   object
#  4   Line_Name        2165 non-null   object
#  5   Machine_Name     2165 non-null   object
#  6   Shift/Hour       2165 non-null   object
#  7   idle_Cycle_time  2164 non-null   float64
#  8   HT               2165 non-null   float64
#  9   MT               2165 non-null   float64
#  10  Stop_time        2165 non-null   int64
#  11  Run_Time         2165 non-null   int64
#  12  Down_Time        2165 non-null   int64
#  13  Total_Count      2165 non-null   int64
#  14  rejection        2165 non-null   int64
#  15  Good_Count       2165 non-null   int64
#  16  Operating_Time   2165 non-null   int64
# ...

# %%
f
# Out:
#             Date En_Name   Bg_Name Plant_Name         Line_Name Machine_Name  \
# 0     04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        HMC-4
# 2     04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        HMC-4
# 5     04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        HMC-4
# 7     04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        HMC-4
# 10    04-01-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing    Nigatta-1
# ...          ...     ...       ...        ...               ...          ...
# 2157  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
# 2158  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
# 2159  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
# 2160  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
# 2163  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Rack Piston        FN3EH
#
# ...

# %%
oee_data.columns
# Out:
# Index(['Date', 'En_Name', 'Bg_Name', 'Plant_Name', 'Line_Name', 'Machine_Name',
#        'Shift/Hour', 'idle_Cycle_time', 'HT', 'MT', 'Stop_time', 'Run_Time',
#        'Down_Time', 'Total_Count', 'rejection', 'Good_Count', 'Operating_Time',
#        'Quality', 'Availability', 'Performance', 'OEE'],
#       dtype='object')

# %%
oee_data.index
# Out:
# RangeIndex(start=0, stop=2165, step=1)

# %%
oee_data.shape
# Out:
# (2165, 21)

# %%
oee_data.dtypes
# Out:
# Date                object
# En_Name             object
# Bg_Name             object
# Plant_Name          object
# Line_Name           object
# Machine_Name        object
# Shift/Hour          object
# idle_Cycle_time    float64
# HT                 float64
# MT                 float64
# Stop_time            int64
# Run_Time             int64
# Down_Time            int64
# Total_Count          int64
# rejection            int64
# Good_Count           int64
# Operating_Time       int64
# Quality            float64
# Availability       float64
# Performance        float64
# OEE                float64
# dtype: object

# %%
oee_data.count()
# Out:
# Date               2165
# En_Name            2165
# Bg_Name            2165
# Plant_Name         2165
# Line_Name          2165
# Machine_Name       2165
# Shift/Hour         2165
# idle_Cycle_time    2164
# HT                 2165
# MT                 2165
# Stop_time          2165
# Run_Time           2165
# Down_Time          2165
# Total_Count        2165
# rejection          2165
# Good_Count         2165
# Operating_Time     2165
# Quality            2165
# Availability       2165
# Performance        2165
# OEE                2165
# dtype: int64

# %%
oee_data.isna()
# Out:
#        Date  En_Name  Bg_Name  Plant_Name  Line_Name  Machine_Name  \
# 0     False    False    False       False      False         False
# 1     False    False    False       False      False         False
# 2     False    False    False       False      False         False
# 3     False    False    False       False      False         False
# 4     False    False    False       False      False         False
# ...     ...      ...      ...         ...        ...           ...
# 2160  False    False    False       False      False         False
# 2161  False    False    False       False      False         False
# 2162  False    False    False       False      False         False
# 2163  False    False    False       False      False         False
# 2164  False    False    False       False      False         False
#
#       Shift/Hour  idle_Cycle_time     HT     MT  ...  Run_Time  Down_Time  \
# 0          False            False  False  False  ...     False      False
# ...

# %%
oee_data.values
# Out:
# array([['04-01-2023', 'RANE', 'ZRAI-SGD', ..., 13.15624346, 807.9491256,
#         106.295754],
#        ['04-01-2023', 'RANE', 'ZRAI-SGD', ..., 100.0, 70.87866109,
#         70.87866109],
#        ['04-01-2023', 'RANE', 'ZRAI-SGD', ..., 100.0, 141.638796,
#         141.638796],
#        ...,
#        ['04/25/2023', 'RANE', 'ZRAI-SGD', ..., 100.0, 0.0, 0.0],
#        ['04/25/2023', 'RANE', 'ZRAI-SGD', ..., 75.14433303, 102.8710069,
#         77.301732],
#        ['04/25/2023', 'RANE', 'ZRAI-SGD', ..., 49.24707195, 90.03397508,
#         44.33909649]], dtype=object)

# %%
oee_data[['Machine_Name','Date','Shift/Hour','Availability','Performance','OEE']]
# Out:
#      Machine_Name        Date Shift/Hour  Availability  Performance  \
# 0           HMC-4  04-01-2023    (06-07)     13.156243   807.949126
# 1           HMC-4  04-01-2023    (07-08)    100.000000    70.878661
# 2           HMC-4  04-01-2023    (08-09)    100.000000   141.638796
# 3           HMC-4  04-01-2023    (09-10)     91.252264    77.575943
# 4           HMC-4  04-01-2023    (10-11)    100.000000    70.957833
# ...           ...         ...        ...           ...          ...
# 2160        FN3EH  04/25/2023    (11-12)     38.680033   228.941685
# 2161        FN3EH  04/25/2023    (12-13)     58.941504    90.170132
# 2162        FN3EH  04/25/2023    (13-14)    100.000000     0.000000
# 2163        FN3EH  04/25/2023    (13-14)     75.144333   102.871007
# 2164        FN3EH  04/25/2023    (14-15)     49.247072    90.033975
#
#              OEE
# 0     106.295754
# 1      70.878661
# 2     141.638796
# 3      70.789804
# 4      70.957833
# ...          ...
# 2160   53.685988
# ...

# %%
oee_data.iloc[:,[4,5,20,19]]
# Out:
#              Line_Name Machine_Name         OEE  Performance
# 0          HFB Housing        HMC-4  106.295754   807.949126
# 1          HFB Housing        HMC-4   70.878661    70.878661
# 2          HFB Housing        HMC-4  141.638796   141.638796
# 3          HFB Housing        HMC-4   70.789804    77.575943
# 4          HFB Housing        HMC-4   70.957833    70.957833
# ...                ...          ...         ...          ...
# 2160  TY54 Rack Piston        FN3EH   53.685988   228.941685
# 2161  TY54 Rack Piston        FN3EH   53.147632    90.170132
# 2162  TY54 Rack Piston        FN3EH    0.000000     0.000000
# 2163  TY54 Rack Piston        FN3EH   77.301732   102.871007
# 2164  TY54 Rack Piston        FN3EH   44.339096    90.033975
#
# [2165 rows x 4 columns]

# %%
~(oee_data.values==50)
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
oee_data.Performance.value_counts(ascending=False,dropna=0)
# Out:
# 0.000000      871
# 93.619393      18
# 93.567251      12
# 93.593315      11
# 96.350975      10
#              ...
# 94.541362       1
# 136.197811      1
# 313.333333      1
# 179.126356      1
# 90.033975       1
# Name: Performance, Length: 1122, dtype: int64

# %%
any(oee_data.isna())
# Out:
# True

# %%
oee_data[oee_data.isna().any(axis=1)]
# Out:
#             Date En_Name   Bg_Name Plant_Name        Line_Name Machine_Name  \
# 2113  04/25/2023    RANE  ZRAI-SGD    Plant 1  HFB Rack Piston        AMS-6
#
#      Shift/Hour  idle_Cycle_time   HT   MT  ...  Run_Time  Down_Time  \
# 2113    (12-13)              NaN  0.0  0.0  ...         9          0
#
#       Total_Count  rejection  Good_Count  Operating_Time  Quality  \
# 2113            0          0           0               9      0.0
#
#       Availability  Performance  OEE
# 2113         100.0          0.0  0.0
#
# [1 rows x 21 columns]

# %%
oee_data.Machine_Name.sort_values(ascending=True,na_position='first')
# Out:
# 1625    ACE U-TURN
# 1834    ACE U-TURN
# 1833    ACE U-TURN
# 327     ACE U-TURN
# 916     ACE U-TURN
#            ...
# 580          T10-2
# 581          T10-2
# 582          T10-2
# 483          T10-2
# 1082         T10-2
# Name: Machine_Name, Length: 2165, dtype: object

# %%
oee_data.sort_values(by=['Machine_Name','OEE','Performance'], ascending=False)
# Out:
#             Date En_Name   Bg_Name Plant_Name         Line_Name Machine_Name  \
# 577   04-07-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        T10-2
# 1387  04/17/2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        T10-2
# 1479  04/18/2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        T10-2
# 875   04-10-2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        T10-2
# 1180  04/13/2023    RANE  ZRAI-SGD    Plant 1       HFB Housing        T10-2
# ...          ...     ...       ...        ...               ...          ...
# 1727  04/20/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
# 1731  04/20/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
# 1733  04/20/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
# 2135  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
# 2142  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#
# ...

# %%
oee_data[oee_data.Machine_Name=='HMC-4'].loc[:,['Line_Name','OEE','Performance',"Availability"]]
# Out:
#         Line_Name         OEE  Performance  Availability
# 0     HFB Housing  106.295754   807.949126     13.156243
# 1     HFB Housing   70.878661    70.878661    100.000000
# 2     HFB Housing  141.638796   141.638796    100.000000
# 3     HFB Housing   70.789804    77.575943     91.252264
# 4     HFB Housing   70.957833    70.957833    100.000000
# ...           ...         ...          ...           ...
# 2061  HFB Housing   71.185969    71.185969    100.000000
# 2062  HFB Housing   71.947102   417.810457     85.213033
# 2063  HFB Housing  142.451254   142.451254    100.000000
# 2064  HFB Housing   71.185969    71.185969    100.000000
# 2065  HFB Housing  142.490945   142.490945    100.000000
#
# [193 rows x 4 columns]

# %%
group=oee_data.groupby('Machine_Name')
group

# %%
covid_data.groupby('continent')

# %%
oee_data.Machine_Name.unique()
# Out:
# array(['HMC-4', 'Nigatta-1', 'AMS-20', 'AMS-6', 'LMW-2', 'ACE-3',
#        'ACE U-TURN', 'AMS-24', 'FN3EH', 'T10-1', 'T10-2'], dtype=object)

# %%
list(oee_data.groupby('Machine_Name'))
# Out:
# [('ACE U-TURN',
#               Date En_Name   Bg_Name Plant_Name         Line_Name Machine_Name  \
#   54    04-01-2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#   55    04-01-2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#   56    04-01-2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#   57    04-01-2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#   58    04-01-2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#   ...          ...     ...       ...        ...               ...          ...
#   2140  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#   2141  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#   2142  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#   2143  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#   2144  04/25/2023    RANE  ZRAI-SGD    Plant 1  TY54 Globic Worm   ACE U-TURN
#
# ...

# %%
list(oee_data)[5][1]
# Out:
# 'a'

# %%
group.groupby.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5852\3528022929.py in <module>
# ----> 1 group.groupby.keys()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     902             return self[attr]
#     903
# --> 904         raise AttributeError(
#     905             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
group.get_group('HMC-4')
# Out:
#             Date En_Name   Bg_Name Plant_Name    Line_Name Machine_Name  \
# 0     04-01-2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
# 1     04-01-2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
# 2     04-01-2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
# 3     04-01-2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
# 4     04-01-2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
# ...          ...     ...       ...        ...          ...          ...
# 2061  04/25/2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
# 2062  04/25/2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
# 2063  04/25/2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
# 2064  04/25/2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
# 2065  04/25/2023    RANE  ZRAI-SGD    Plant 1  HFB Housing        HMC-4
#
#      Shift/Hour  idle_Cycle_time          HT           MT  ...  Run_Time  \
# ...

# %%
import numpy as np
oee_data.groupby('Machine_Name')[['Performance','OEE']].agg([np.max,np.var])
# Out:
#               Performance                        OEE
#                      amax            var        amax          var
# Machine_Name
# ACE U-TURN     198.662207    1841.715318  102.927237  1427.422939
# ACE-3         2492.660550   55280.340792  162.865905  1479.719825
# AMS-20         640.000000    6599.091672  245.682451  1861.833698
# AMS-24        5124.444444  229640.403057  258.520179  2287.113934
# AMS-6         1446.601942   33999.678897  376.044568  2802.605035
# FN3EH          859.459459    8978.837729  127.018545  2041.633998
# HMC-4         9132.142857  517924.592191  573.961841  6821.565379
# LMW-2         1511.111111   21382.632411  122.109989  1472.204538
# Nigatta-1     2902.612827   77260.829325  374.686367  3681.435166
# T10-1         2238.095238   78074.096943  637.787056  7466.616723
# T10-2         1593.427230   56659.615424  205.323654  1977.610361

# %%
oee_data.groupby('Machine_Name')[['Performance','OEE']].agg({'OEE':['min','max','count']})
# Out:
#               OEE
#               min         max count
# Machine_Name
# ACE U-TURN    0.0  102.927237   205
# ACE-3         0.0  162.865905   200
# AMS-20        0.0  245.682451   198
# AMS-24        0.0  258.520179   201
# AMS-6         0.0  376.044568   202
# FN3EH         0.0  127.018545   199
# HMC-4         0.0  573.961841   193
# LMW-2         0.0  122.109989   202
# Nigatta-1     0.0  374.686367   205
# T10-1         0.0  637.787056   182
# T10-2         0.0  205.323654   178

# %%
oee_data['OEE'].mean()
# Out:
# 52.324930491107665

# %%
group.get_group('HMC-4')[["OEE"]].mean()
# Out:
# OEE    93.20491
# dtype: float64

# %%
oee_data.isna().sum().sum()
# Out:
# 1

# %%
oee_data.isnull().sum()
# Out:
# Date               0
# En_Name            0
# Bg_Name            0
# Plant_Name         0
# Line_Name          0
# Machine_Name       0
# Shift/Hour         0
# idle_Cycle_time    1
# HT                 0
# MT                 0
# Stop_time          0
# Run_Time           0
# Down_Time          0
# Total_Count        0
# rejection          0
# Good_Count         0
# Operating_Time     0
# Quality            0
# Availability       0
# Performance        0
# OEE                0
# dtype: int64

# %%
 oee_data.notnull().sum()
# Out:
# Date               2165
# En_Name            2165
# Bg_Name            2165
# Plant_Name         2165
# Line_Name          2165
# Machine_Name       2165
# Shift/Hour         2165
# idle_Cycle_time    2164
# HT                 2165
# MT                 2165
# Stop_time          2165
# Run_Time           2165
# Down_Time          2165
# Total_Count        2165
# rejection          2165
# Good_Count         2165
# Operating_Time     2165
# Quality            2165
# Availability       2165
# Performance        2165
# OEE                2165
# dtype: int64

# %%
oee_data[oee_data.isna().any(axis=1)]
# Out:
#             Date En_Name   Bg_Name Plant_Name        Line_Name Machine_Name  \
# 2113  04/25/2023    RANE  ZRAI-SGD    Plant 1  HFB Rack Piston        AMS-6
#
#      Shift/Hour  idle_Cycle_time   HT   MT  ...  Run_Time  Down_Time  \
# 2113    (12-13)              NaN  0.0  0.0  ...         9          0
#
#       Total_Count  rejection  Good_Count  Operating_Time  Quality  \
# 2113            0          0           0               9      0.0
#
#       Availability  Performance  OEE
# 2113         100.0          0.0  0.0
#
# [1 rows x 21 columns]

# %%
oee_data.loc[1:20,:]
# Out:
#           Date En_Name   Bg_Name Plant_Name        Line_Name Machine_Name  \
# 1   04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing        HMC-4
# 2   04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing        HMC-4
# 3   04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing        HMC-4
# 4   04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing        HMC-4
# 5   04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing        HMC-4
# 6   04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing        HMC-4
# 7   04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing        HMC-4
# 8   04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing        HMC-4
# 9   04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing    Nigatta-1
# 10  04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing    Nigatta-1
# 11  04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing    Nigatta-1
# 12  04-01-2023    RANE  ZRAI-SGD    Plant 1      HFB Housing    Nigatta-1
# ...

# %%
oee_data.duplicated(keep='first')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2160    False
# 2161    False
# 2162    False
# 2163    False
# 2164    False
# Length: 2165, dtype: bool

# %%
oee_data[oee_data.duplicated(keep='last')]
# Out:
# Empty DataFrame
# Columns: [Date, En_Name, Bg_Name, Plant_Name, Line_Name, Machine_Name, Shift/Hour, idle_Cycle_time, HT, MT, Stop_time, Run_Time, Down_Time, Total_Count, rejection, Good_Count, Operating_Time, Quality, Availability, Performance, OEE]
# Index: []
#
# [0 rows x 21 columns]

# %%
tidy_oee = oee_data.stack()
tidy_oee
# Out:
# 0     Date               04-01-2023
#       En_Name                  RANE
#       Bg_Name              ZRAI-SGD
#       Plant_Name            Plant 1
#       Line_Name         HFB Housing
#                            ...
# 2164  Operating_Time             60
#       Quality                 100.0
#       Availability        49.247072
#       Performance         90.033975
#       OEE                 44.339096
# Length: 45464, dtype: object

# %%
type(tidy_oee)
# Out:
# pandas.core.series.Series

# %%
tidy_oee=tidy_oee.reset_index()
tidy_oee
# Out:
#        index  level_0         level_1            0
# 0          0        0            Date   04-01-2023
# 1          1        0         En_Name         RANE
# 2          2        0         Bg_Name     ZRAI-SGD
# 3          3        0      Plant_Name      Plant 1
# 4          4        0       Line_Name  HFB Housing
# ...      ...      ...             ...          ...
# 45459  45459     2164  Operating_Time           60
# 45460  45460     2164         Quality        100.0
# 45461  45461     2164    Availability    49.247072
# 45462  45462     2164     Performance    90.033975
# 45463  45463     2164             OEE    44.339096
#
# [45464 rows x 4 columns]

# %%
oee_data.corr()
# Out:
#                  idle_Cycle_time        HT        MT  Stop_time  Run_Time  \
# idle_Cycle_time         1.000000 -0.094547  0.127829  -0.174970  0.420845
# HT                     -0.094547  1.000000  0.156410   0.300430 -0.050240
# MT                      0.127829  0.156410  1.000000  -0.049853 -0.018504
# Stop_time              -0.174970  0.300430 -0.049853   1.000000  0.353102
# Run_Time                0.420845 -0.050240 -0.018504   0.353102  1.000000
# Down_Time              -0.095139  0.050679  0.139366  -0.405018 -0.681215
# Total_Count            -0.322616  0.223551 -0.047699   0.498393  0.241730
# rejection               0.058227  0.066846  0.057088  -0.002036  0.015299
# Good_Count             -0.332202  0.217750 -0.054744   0.502997  0.242073
# Operating_Time          0.316904  0.053770  0.161511  -0.006430  0.243122
# Quality                 0.083817  0.554727  0.170662   0.375736  0.432227
# Availability            0.246233  0.008511 -0.063165   0.496066  0.868301
# ...

# %%
tidy_oee.index
# Out:
# MultiIndex([(   0,            'Date'),
#             (   0,         'En_Name'),
#             (   0,         'Bg_Name'),
#             (   0,      'Plant_Name'),
#             (   0,       'Line_Name'),
#             (   0,    'Machine_Name'),
#             (   0,      'Shift/Hour'),
#             (   0, 'idle_Cycle_time'),
#             (   0,              'HT'),
#             (   0,              'MT'),
#             ...
#             (2164,        'Run_Time'),
#             (2164,       'Down_Time'),
#             (2164,     'Total_Count'),
#             (2164,       'rejection'),
#             (2164,      'Good_Count'),
#             (2164,  'Operating_Time'),
#             (2164,         'Quality'),
#             (2164,    'Availability'),
#             (2164,     'Performance'),
#             (2164,             'OEE')],
#            length=45464)

# %%
grouped_continents.get_group('America')[["deaths"]].mean()

# %%
oee_data.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1616\3075368137.py in <module>
# ----> 1 oee_data.corr()
#
# NameError: name 'oee_data' is not defined

# %%
oee_data.agg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5852\350971345.py in <module>
# ----> 1 oee_data.agg()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in aggregate(self, func, axis, *args, **kwargs)
#    8653         axis = self._get_axis_number(axis)
#    8654
# -> 8655         relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    8656
#    8657         op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in reconstruct_func(func, **kwargs)
#    1264         elif func is None:
#    1265             # nicer error message
# -> 1266             raise TypeError("Must provide 'func' or tuples of '(column, aggfunc).")
#    1267
#    1268     if relabeling:
#
# TypeError: Must provide 'func' or tuples of '(column, aggfunc).

# %%
# Import libraries
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# create a sample dataframe
data= pd.read_csv(r"C:\Users\15878\DA\SGD_Data.csv")
data
data = pd.DataFrame({'Availability': [1200]})
#Data_pred = pd.DataFrame({'Down_Time':[1200]})
# create a MinMaxScaler object
scaler = MinMaxScaler()

# select columns to scale
cols_to_scale = ['Availability']
#cols_to_scale1 = ['Down_Time']

# apply Min-Max scaling to selected columns
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
#Data_pred[cols_to_scale1] = scaler.fit_transform(Data_pred[cols_to_scale1] )
# Split data into features and target variable
X = df[cols_to_scale]
y = df["Down_Time"]
print(X,y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[cols_to_scale],y, train_size=0.7,test_size=0.3, random_state=42)
# Create a Decision Tree Regressor
dtr = DecisionTreeRegressor(max_depth=5, random_state=42)

# Train the regressor on the training data
dtr.fit(X_train, y_train)

# Predict the target variable for the test data
y_pred = dtr.predict(X_test)

# Calculate the mean squared error of the predictions
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
#       Availability
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.600074
# ...            ...
# 1205      0.471207
# 1206      0.977755
# 1207      0.703322
# 1208      0.572130
# 1209      0.836662
#
# [1210 rows x 1 columns] 0       509
# 1       270
# 2       208
# 3        30
# 4       144
#        ...
# 1205     16
# 1206      8
# 1207    109
# 1208    199
# 1209     62
# Name: Down_Time, Length: 1210, dtype: int64
# Mean Squared Error: 9124.736032755443
